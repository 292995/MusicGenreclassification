# %% [markdown]
# # Music Genre Classification - Data Exploration

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load audio file
audio, sr = librosa.load('path/to/audio/file.mp3', duration=30)
